# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR

# %%
data = pd.read_csv("data/preprocessed.csv", index_col=0)
data.head()
# Out:
#    Rating      MRP          Processor  RAM          OS     Storage   Brand  \
# 0     4.2  25490.0  Celeron Dual Core    4  Windows 11  512 GB SSD      HP
# 1     3.8  22490.0            Core i5    4  Windows 11  512 GB SSD      HP
# 2     4.1  25685.0  Celeron Dual Core    8  Windows 11  256 GB SSD  Lenovo
# 3     4.4  51990.0            Core i5    8  Windows 11  512 GB SSD    ASUS
# 4     4.2  38990.0            Core i3    8  Windows 11  512 GB SSD    ASUS
#
#    OS_arch RAM_Type Processor_brand
# 0       64   LPDDR4           Intel
# 1       64  LPDDR4X           Intel
# 2       64     DDR4           Intel
# 3       64     DDR4           Intel
# 4       64     DDR4           Intel

# %%
cols = data.dtypes[data.dtypes == "object"].index
for col in cols:
    data[col] = data[col].apply(lambda x: x.strip())
data.head()
# Out:
#    Rating      MRP          Processor  RAM          OS     Storage   Brand  \
# 0     4.2  25490.0  Celeron Dual Core    4  Windows 11  512 GB SSD      HP
# 1     3.8  22490.0            Core i5    4  Windows 11  512 GB SSD      HP
# 2     4.1  25685.0  Celeron Dual Core    8  Windows 11  256 GB SSD  Lenovo
# 3     4.4  51990.0            Core i5    8  Windows 11  512 GB SSD    ASUS
# 4     4.2  38990.0            Core i3    8  Windows 11  512 GB SSD    ASUS
#
#    OS_arch RAM_Type Processor_brand
# 0       64   LPDDR4           Intel
# 1       64  LPDDR4X           Intel
# 2       64     DDR4           Intel
# 3       64     DDR4           Intel
# 4       64     DDR4           Intel

# %% [markdown]
# ### Relation between Rating and MRP

# %%
sns.lineplot(x=data.Rating, y=data.MRP)
plt.show()

# %% [markdown]
# ### Price Variation with Processor

# %%
chart = sns.barplot(x=data.Processor, y=data.MRP)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.show()

# %% [markdown]
# ### Price Variation with OS

# %%
chart = sns.barplot(x=data.OS, y=data.MRP)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.show()

# %% [markdown]
# ### Price Variation due to Brand Influence

# %%
chart = sns.barplot(x=data.Brand, y=data.MRP)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.show()

# %% [markdown]
# ### Ram Size influence on Price

# %%
chart = sns.barplot(x=data.RAM, y=data.MRP)
plt.show()
